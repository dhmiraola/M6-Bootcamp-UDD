# %%
# !pip install stopwords

# %%
# pip install wordcloud

# %%
# !pip install requests beautifulsoup4

# %%
# !pip install nltk

# %%
# https://www.bcentral.cl/inicio

# %%
import requests
from bs4 import BeautifulSoup

# URL de la página web que deseas hacer scraping
url = 'https://www.bcentral.cl/inicio'

# Realizar una petición GET a la página web
response = requests.get(url)

# Verificar que la petición fue exitosa (código de estado HTTP 200)
if response.status_code == 200:
    # Parsear el contenido HTML de la página web usando BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Extraer el título de la página
    title = soup.title.text  # .text extrae el texto del elemento
    
    print("Título de la página:", title)
else:
    print("Error al acceder a la página:", response.status_code)
# Out:
# Título de la página: Inicio - Banco Central de Chile

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.bcentral.cl/inicio'
response = requests.get(url)

if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Extraer el título de la página
    title = soup.title.text
    print("Título de la página:", title)
    
    # Extraer todos los enlaces de la página
    links = soup.find_all('a')  # Encuentra todos los elementos <a>
    for link in links:
        href = link.get('href')  # Obtiene el atributo href de cada enlace
        if href:
            print(href)
else:
    print("Error al acceder a la página:", response.status_code)
# Out:
# Título de la página: Inicio - Banco Central de Chile
# #main-content
# #0
# #0
# #0
# /c/portal/update_language?p_l_id=3297165&redirect=%2Finicio&languageId=en_US
# https://www.bcentral.cl/web/banco-central
# #;
# https://www.bcentral.cl/web/banco-central/columna_1
# https://www.bcentral.cl/web/banco-central/el-banco/gobierno-corporativo
# https://www.bcentral.cl/web/banco-central/el-banco/gobierno-corporativo/funciones-del-banco
# https://www.bcentral.cl/web/banco-central/el-banco/gobierno-corporativo/personas
# https://www.bcentral.cl/web/banco-central/el-banco/gobierno-corporativo/historia
# https://www.bcentral.cl/web/banco-central/el-banco/gobierno-corporativo/planificacion-estrategica
# https://www.bcentral.cl/contenido/-/detalle/memoria-anual-integrada_2023
# https://www.bcentral.cl/web/banco-central/el-banco/gobierno-corporativo/evaluaciones-externas
# https://www.bcentral.cl/web/banco-central/el-banco/gobierno-corporativo/relaciones-internacionales
# https://www.bcentral.cl/web/banco-central/el-banco/relacion-con-la-ciudadania
# https://www.bcentral.cl/web/banco-central/el-banco/relacion-con-la-ciudadania/patrimonio
# https://portalbiblioteca.bcentral.cl
# http://www.centralentuvida.cl
# https://www.bcentral.cl/web/banco-central/columna_2
# https://www.bcentral.cl/web/banco-central/el-banco/transparencia-y-probidad
# https://www.bcentral.cl/web/banco-central/el-banco/transparencia/transparencia-activa
# https://www.bcentral.cl/web/banco-central/el-banco/transparencia/acceso-a-la-informacion
# https://leylobby.bcentral.cl/
# https://www.bcentral.cl/web/banco-central/el-banco/transparencia/declaraciones-de-intereses-y-patrimonio
# https://agendapublica.bcentral.cl/
# https://agendapublica.bcentral.cl/agenda/listar-registro-cargo
# https://www.bcentral.cl/web/banco-central/el-banco/transparencia/preguntas-frecuentes
# https://www.bcentral.cl/web/banco-central/columna_3
# https://www.bcentral.cl/web/banco-central/el-banco/trabaja-en-el-bc
# https://www.bcentral.cl/web/banco-central/el-banco/trabaja-en-el-bc/oportunidades-de-trabajo
# https://www.bcentral.cl/web/banco-central/el-banco/compras-y-proveedores
# https://www.bcentral.cl/web/banco-central/el-banco/compras-y-proveedores/licitaciones-y-cotizaciones-publicas
# https://www.bcentral.cl/web/banco-central/el-banco/compras-y-proveedores/portal-de-compras
# https://www.bcentral.cl/web/banco-central/el-banco/compras-y-proveedores/portal-de-proveedores
# https://www.bcentral.cl/web/banco-central/el-banco/compras-y-proveedores/portal-de-pago
# https://www.bcentral.cl/web/banco-central/el-banco/compras-y-proveedores/canal-de-denuncias-para-oferentes-y-proveedores
# https://repositoriodigital.bcentral.cl/
# https://www.bcentral.cl/contenido/-/detalle/bcch-abre-postulaciones-practicas-2025
# #;
# https://www.bcentral.cl/web/banco-central/columna_11
# https://www.bcentral.cl/web/banco-central/areas/politica-monetaria
# https://www.bcentral.cl/web/banco-central/areas/politica-monetaria/informe-de-politica-monetaria
# https://www.bcentral.cl/web/banco-central/areas/politica-monetaria/reunion-de-politica-monetaria-rpm
# https://www.bcentral.cl/es/areas/politica-monetaria/reunion-de-politica-monetaria-rpm/documentacion-rpm
# https://www.bcentral.cl/web/banco-central/areas/politica-monetaria/informe-de-percepciones-de-negocios-ipn
# https://www.bcentral.cl/web/banco-central/areas/politica-financiera
# https://www.bcentral.cl/web/banco-central/areas/politica-financiera/informe-de-estabilidad-financiera
# https://www.bcentral.cl/web/banco-central/areas/politica-financiera/informe-de-sistemas-de-pago
# https://www.bcentral.cl/web/banco-central/areas/politica-financiera/reunion-de-politica-financiera-rpf
# https://www.bcentral.cl/web/banco-central/areas/politica-financiera/regulacion-prudencial
# https://www.bcentral.cl/web/banco-central/areas/politica-financiera/regulacion-cambiaria
# https://www.bcentral.cl/web/banco-central/columna_21
# https://www.bcentral.cl/web/banco-central/areas/mercados-financieros
# https://www.bcentral.cl/web/banco-central/areas/mercados-financieros/operaciones-de-mercado-abierto
# https://www.bcentral.cl/web/banco-central/areas/mercados-financieros/operaciones-de-mercado-abierto-agencia-fiscal
# https://www.bcentral.cl/web/banco-central/areas/mercados-financieros/gestion-de-reservas-internacionales
# https://www.bcentral.cl/web/banco-central/areas/mercados-financieros/comite-de-mercados-nacionales
# https://www.bcentral.cl/web/banco-central/areas/mercados-financieros/fcic
# https://www.bcentral.cl/web/banco-central/areas/mercados-financieros/sistemas
# https://www.bcentral.cl/web/banco-central/medidas-excepcionales
# https://www.bcentral.cl/web/banco-central/areas/estadisticas
# https://si3.bcentral.cl/siete
# https://www.bcentral.cl/es/web/banco-central/noticias-y-publicaciones/prensa/calendario-eventos-economicos
# https://www.bcentral.cl/web/banco-central/areas/estadisticas/reportes-al-bcch
# https://www.bcentral.cl/web/banco-central/areas/estadisticas/preguntas-frecuentes-estadisticas
# https://www.bcentral.cl/web/banco-central/columna_31
# https://www.bcentral.cl/web/banco-central/areas/normativa
# https://www.bcentral.cl/web/banco-central/areas/normativas/compendio-de-normas-financieras
# https://www.bcentral.cl/web/banco-central/areas/compendio-de-normas-de-cambios-internacionales
# https://www.bcentral.cl/web/banco-central/compendio-de-normas-de-cambios-internacionales-a-contar-de-2026
# https://www.bcentral.cl/web/banco-central/areas/normativas/compendio-de-normas-monetarias-y-financieras
# https://www.bcentral.cl/web/banco-central/areas/normativa/consultas-publicas
# https://www.bcentral.cl/web/banco-central/areas/observatorio-tecnologico
# https://www.bcentral.cl/web/banco-central/areas/observatorio-tecnologico/exploracion-de-monedas-digitales-de-banco-central
# https://www.bcentral.cl/web/banco-central/columna_41
# https://www.bcentral.cl/web/banco-central/areas/sistemas-de-pagos
# https://www.bcentral.cl/web/banco-central/areas/encuestas-economicas
# https://www.bcentral.cl/web/banco-central/areas/investigacion
# https://www.billetesymonedas.cl/
# https://www.bcentral.cl/web/banco-central/noticias-y-publicaciones
# https://www.bcentral.cl/web/banco-central/columna_12
# https://www.bcentral.cl/web/banco-central/noticias-y-publicaciones/prensa
# https://www.bcentral.cl/web/banco-central/nuevo-buscador?category=35742&categorias=35737&temas=35742&type=com.liferay.journal.model.JournalArticle&sort=createDate-
# https://www.bcentral.cl/web/banco-central/nuevo-buscador?category=3536980&categorias=35737&temas=3536980&type=com.liferay.journal.model.JournalArticle&sort=createDate-
# https://www.bcentral.cl/web/banco-central/nuevo-buscador?category=35744&categorias=35737&temas=35744&type=com.liferay.journal.model.JournalArticle&sort=createDate-
# https://www.bcentral.cl/web/banco-central/nuevo-buscador?category=35743&categorias=35737&temas=35743&type=com.liferay.journal.model.JournalArticle&sort=createDate-
# https://www.bcentral.cl/web/banco-central/nuevo-buscador?category=168138&categorias=35737&temas=168138&type=com.liferay.journal.model.JournalArticle&sort=createDate-
# https://www.bcentral.cl/web/banco-central/noticias-y-publicaciones/prensa/calendario-eventos-economicos
# https://www.bcentral.cl/web/banco-central/noticias-y-publicaciones/prensa/calendario-de-politica-monetaria-y-financiera
# https://www.bcentral.cl/web/banco-central/noticias-y-publicaciones/prensa/politica-de-comunicaciones
# https://www.bcentral.cl/web/banco-central/publicaciones
# https://www.bcentral.cl/web/banco-central/nuevo-buscador?category=35825&categorias=35741&temas=35825&type=com.liferay.journal.model.JournalArticle&sort=createDate-
# https://www.bcentral.cl/web/banco-central/nuevo-buscador?category=35828&categorias=35741&temas=35828&type=com.liferay.journal.model.JournalArticle&sort=createDate-
# https://www.bcentral.cl/web/banco-central/nuevo-buscador?category=35829&categorias=35741&temas=35829&type=com.liferay.journal.model.JournalArticle&sort=createDate-
# https://www.bcentral.cl/web/banco-central/nuevo-buscador?category=35830&categorias=35741&temas=35830&type=com.liferay.journal.model.JournalArticle&sort=createDate-
# https://www.bcentral.cl/web/banco-central/columna_22
# https://www.bcentral.cl/web/banco-central/noticias-y-publicaciones/eventos
# https://www.bcentral.cl/web/banco-central/nuevo-buscador?category=35748&categorias=35738&temas=35748&type=com.liferay.journal.model.JournalArticle&sort=createDate-
# https://www.bcentral.cl/web/banco-central/nuevo-buscador?category=35749&categorias=35738&temas=35749&type=com.liferay.journal.model.JournalArticle&sort=createDate-
# https://www.bcentral.cl/web/banco-central/nuevo-buscador?category=35750&categorias=35738&temas=35750&type=com.liferay.journal.model.JournalArticle&sort=createDate-
# https://www.bcentral.cl/web/banco-central/nuevo-buscador?category=35751&categorias=35738&temas=35751&type=com.liferay.journal.model.JournalArticle&sort=createDate-
# https://www.bcentral.cl/web/banco-central/nuevo-buscador?category=35752&categorias=35738&temas=35752&type=com.liferay.journal.model.JournalArticle&sort=createDate-
# https://www.bcentral.cl/web/banco-central/columna_32
# https://www.bcentral.cl/web/banco-central/publicaciones-normativas1
# https://www.bcentral.cl/web/banco-central/nuevo-buscador?category=35814&categorias=35739&temas=35814&type=com.liferay.journal.model.JournalArticle&sort=sortableDate_sortable-
# https://www.bcentral.cl/web/banco-central/nuevo-buscador?category=35813&categorias=35739&temas=35813&type=com.liferay.journal.model.JournalArticle&sort=sortableDate_sortable-
# https://www.bcentral.cl/web/banco-central/nuevo-buscador?category=35811&categorias=35739&temas=35811&type=com.liferay.journal.model.JournalArticle&sort=sortableDate_sortable-
# https://www.bcentral.cl/web/banco-central/nuevo-buscador?category=121519&categorias=35739&temas=121519&type=com.liferay.journal.model.JournalArticle&sort=sortableDate_sortable-
# https://www.bcentral.cl/web/banco-central/nuevo-buscador?category=35818&categorias=35739&temas=35818&type=com.liferay.journal.model.JournalArticle&sort=sortableDate_sortable-
# https://www.bcentral.cl/es/web/banco-central/noticias-y-publicaciones/prensa/calendario-eventos-economicos
# https://www.bcentral.cl/web/banco-central/contacto-central
# https://www.bcentral.cl/web/banco-central/blogs
# https://www.bcentral.cl/web/banco-central/contenido/-/detalle/edep-trimestre-movil-septiembre-octubre-noviembre-2024
# https://www.bcentral.cl/web/banco-central/areas/estadisticas/estadisticas-experimentales/iali#ancla-2
# /web/banco-central/areas/politica-monetaria/reunion-de-politica-monetaria-rpm#ancla-rpm
# https://www.bcentral.cl/web/banco-central/contenido/-/detalle/cuentas-nacionales-por-sector-institucional-tercer-trimestre-de-2024
# https://www.bcentral.cl/web/banco-central/areas/estadisticas/estadisticas-experimentales/ide#ancla-3
# /contenido/-/detalle/programa-operaciones
# /web/banco-central/areas/estadisticas/reportes-al-bcch
# #carouselExampleIndicators
# #carouselExampleIndicators
# https://regularizacionoperacionesdecambios.bcentral.cl/
# https://si3.bcentral.cl/Siete/ES/Siete/Cuadro/CAP_PRECIOS/MN_CAP_PRECIOS/UF_IVP_DIARIO/UF_IVP_DIARIO
# https://si3.bcentral.cl/Siete/ES/Siete/Cuadro/CAP_PRECIOS/MN_CAP_PRECIOS/UF_IVP_UTM/UF_IVP_UTM
# https://si3.bcentral.cl/Siete/ES/Siete/Cuadro/CAP_TIPO_CAMBIO/MN_TIPO_CAMBIO4/DOLAR_OBS_ADO
# https://www.bolchile.com/dollar
# https://si3.bcentral.cl/Indicadoressiete/secure/Serie.aspx?gcode=PRE_EUR¶m=cgBnAE8AOQBlAGcAIwBiAFUALQBsAEcAYgBOAEkASQBCAEcAegBFAFkAeABkADgASAA2AG8AdgB2AFMAUgBYADIAQwBzAEEARQBMAG8ASgBWADQATABrAGQAZAB1ADIAeQBBAFAAZwBhADIAbABWAHcAXwBXAGgATAAkAFIAVAB1AEIAbAB3AFoAdQBRAFgAZwA5AHgAdgAwACQATwBZADcAMwAuAGIARwBFAFIASwAuAHQA
# https://si3.bcentral.cl/Siete/ES/Siete/Cuadro/CAP_PRECIOS/MN_CAP_PRECIOS/IPC_VAREMP_2023
# https://si3.bcentral.cl/Siete/ES/Siete/Cuadro/CAP_TASA_INTERES/MN_TASA_INTERES_09/TPM_C1/T12
# https://si3.bcentral.cl/Indicadoressiete/secure/Indicadoresdiarios.aspx
# /web/banco-central/areas/observatorio-tecnologico/exploracion-de-monedas-digitales-de-banco-central
# https://si3.bcentral.cl/estadisticas/Principal1/enlaces/aplicaciones/Busqueda_ES.html
# /web/banco-central/noticias-y-publicaciones/prensa/calendario-eventos-economicos
# https://si3.bcentral.cl/siete
# #pills-1
# #pills-2
# #pills-3
# #pills-4
# #pills-5
# https://si3.bcentral.cl/estadisticas/Principal1/Metodologias/EC/PARIDADES/Dolar_observado.pdf
# https://www.bcentral.cl/documents/33528/2546026/Paridades+Ficha+metodologica.pdf
# https://si3.bcentral.cl/estadisticas/Principal1/Metodologias/EMF/UF.pdf
# https://si3.bcentral.cl/siete
# https://si3.bcentral.cl/siete
# https://si3.bcentral.cl/siete
# /areas/politica-monetaria
# /areas/politica-financiera
# /areas/mercados-financieros
# /areas/estadisticas
# /areas/investigacion
# /areas/normativa
# /web/banco-central/el-banco/transparencia-y-probidad
# https://www.centralentuvida.cl
# https://www.museobancocentral.cl
# https://repositoriodigital.bcentral.cl/
# https://www.billetesymonedas.cl
# https://portalbiblioteca.bcentral.cl/inicio
# #sliderMain
# #sliderMain
# https://www.centralentuvida.cl/
# https://www.billetesymonedas.cl
# https://www.museobancocentral.cl
# https://si3.bcentral.cl/siete
# https://portalbiblioteca.bcentral.cl
# https://repositoriodigital.bcentral.cl/
# https://si3.bcentral.cl/estadisticas/Principal1/enlaces/aplicaciones/index.html
# /web/banco-central/el-banco/trabaja-en-el-bc/oportunidades-de-trabajo
# /web/banco-central/el-banco/transparencia/transparencia-activa
# /web/banco-central/el-banco/transparencia/acceso-a-la-informacion
# https://leylobby.bcentral.cl/
# https://www.leychile.cl/Navegar?idNorma=30216
# https://www.estrategiaantilavado.cl/
# /web/banco-central/contacto-central
# /web/banco-central/preguntas-frecuentes
# https://coleccion.bcentral.cl/web/coleccion-de-pinturas
# https://my.matterport.com/show/?m=isFyFcFnTJe
# https://www.museobancocentral.cl/tour_virtual.html
# /web/banco-central/suscripcion
# /web/banco-central/condiciones-de-uso
# /web/banco-central/mapa-web
# https://www.youtube.com/watch?v=uXVmVXBtSiM
# https://www.youtube.com/user/BancoCentralChile
# https://www.flickr.com/photos/bancocentraldechile/
# https://twitter.com/bcentralchile
# https://www.instagram.com/bancocentralchile/
# javascript:
# #
# #0
# #0

# %%
import requests
from bs4 import BeautifulSoup
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# URL de la página web que deseas hacer scraping
url = 'https://www.bcentral.cl/inicio'
response = requests.get(url)

if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Extraer todos los textos de enlaces de la página
    links_text = ' '.join(link.text for link in soup.find_all('a') if link.text)
    
    # Generar la nube de palabras
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(links_text)
    
    # Mostrar la nube de palabras
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()
else:
    print("Error al acceder a la página:", response.status_code)

# %%
import nltk
from nltk.corpus import stopwords

# Descargar la lista de stopwords de NLTK
nltk.download('stopwords')

# Cargar las stopwords en español 
stop_words = set(stopwords.words('spanish'))

# Filtrar las stopwords de tu texto
filtered_text = ' '.join(word for word in links_text.split() if word.lower() not in stop_words)

# Ahora, generar la nube de palabras usando el texto filtrado
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(filtered_text)

# Mostrar la nube de palabras
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Diego\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# URL de la página del Banco Central
url = "https://www.bcentral.cl/"  # Cambia por la URL específica si es necesario

# Realizar solicitud HTTP
res = requests.get(url)

# Analizar el HTML con BeautifulSoup
soup = BeautifulSoup(res.text, 'html.parser')

# Extraer texto de la página
page_text = soup.get_text(separator=' ')  # Extrae todo el texto visible en la página

# Cargar tus stopwords personalizadas desde un archivo
with open('stopwords-es.txt', 'r', encoding='utf-8') as f:
    custom_stop_words = set(f.read().splitlines())  # Crear un set de stopwords

# Filtrar las stopwords del texto extraído
filtered_text = ' '.join(word for word in page_text.split() if word.lower() not in custom_stop_words)

# Generar la nube de palabras usando el texto filtrado
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(filtered_text)

# Mostrar la nube de palabras
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
