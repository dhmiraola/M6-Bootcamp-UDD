# %% [markdown]
# **RECONOCIMIENTO DE ENTIDADES NOMBRADAS (NER)**
#
#
#
# Este Notebook permite extraer entidades nombradas a partir de textos en lenguaje natural.
#
# Utilizaremos el [conjunto de etiquetas de entidades estándar de SPacy](https://spacy.io/api/annotation#pos-tagging).
#
# Primero, necesitamos instalar algunos paquetes (en caso de que no estén instalados):

# %%
# !pip install spacy
# !python -m spacy download es_core_news_sm

# %% [markdown]
# Luego, necesitamos cargar algunas bibliotecas y métodos:

# %%
import es_core_news_sm
from spacy import displacy

# %% [markdown]
# Definimos la función **ExtraerEntidades(texto)**, que realiza el etiquetado NER para un texto de entrada, y retorna  una lista con todas las entidades

# %%
def ExtraerEntidades(texto):
   doc = nlp(texto) 
   entities = [NE for NE in doc.ents]
   return(entities)

# %% [markdown]
# Dado que se reconocen todas las entidades existentes, definimos además una función **FiltrarEntidades(Entidades, tipo_entidad)**, que permite extraer desde las entidades reconocidas solo aquellas de un cierto tipo (i.e., PERsonas, ORGanizaciones, etc):

# %%
def FiltrarEntidades(Entidades, tipo_entidad):
   entidades = list()
   for Ent in Entidades:
     if (Ent.label_ == tipo_entidad):
       entidades.append(Ent.text)
   return(entidades)

# %% [markdown]
# Ahora, realizamos nuestro programa principal, y leyendo un archivo de texto simple:

# %%
nlp = es_core_news_sm.load()
texto = open('C:/Users/Usuario/Big Data/Text Mining\Clase 1\clase 1/d20.txt', 'r',encoding="latin1").read()

# %% [markdown]
# Finalmente, invocamos nuetras funciones para realizar la extracción de entidades, y luego filtramos para que sólo entregue entidades de tipo **organización** (ORG):

# %%
entidades= ExtraerEntidades(texto)
print(entidades)
entidadesTipo = FiltrarEntidades(entidades,'PER')
print(entidadesTipo)
# Out:
# [fÃºtbol, Ante, Ãºltimas horas, Deportes Quatro de EspaÃ±a, prÃ³xima, Europa, Juventus, Cristiano Ronaldo, bÃºsqueda, Su destino, ParÃ­s Saint Germain, ©s.]
# ['Deportes Quatro de EspaÃ±a', 'Cristiano Ronaldo', '©s.']

# %% [markdown]
# Alternativamente, dependiendo de la aplicación, SpaCY provee un método que permite mostrar visualmente el mismo análisis realizado previamente, utilizando un servidor de Spacy. Para esto, primero se deben realizar la tarea de NLP para obtener la lista de entidades de un texto, y luego la indicamos a SpaCY que visualice sólo las entidades (*style="ent"*).
#
# Note que a diferencia del ejemplo previo esta alternativa sólo permite visualizar, no podemos filtrar entidades directamente.

# %%
doc = nlp(texto)
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Poema
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  1<br><br>Cuerpo de mujer, blancas colinas, muslos blancos,<br>te pareces al mundo en tu actitud de entrega.<br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mi cuerpo de labriego salvaje te socava
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# <br>y hace saltar el hijo del fondo de la tierra.<br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fui
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  solo como un
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tÃºnel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# .
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     De mÃ­
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  huÃ­an los pÃ¡jaros<br>y en
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mÃ­
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  la noche entraba su invasiÃ³n poderosa.<br>Para sobrevivirme te forjÃ
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ©
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  como un arma,<br>como una flecha en mi arco, como una piedra en mi honda.<br>Pero cae la hora de la venganza, y te amo.<br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cuerpo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  de piel, de musgo, de leche Ã¡vida y firme.<br>
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ah
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  los vasos del pecho! Ah los ojos de ausencia!<br>
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ah
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  las rosas del pubis! Ah tu voz lenta y triste!<br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cuerpo de mujer mÃ­a
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , persistirÃ¡ en tu gracia.<br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mi sed
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# , mi ansia sin limite, mi camino indeciso!<br>
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Oscuros
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  cauces donde la sed eterna sigue,<br>y la fatiga sigue, y el dolor infinito.<br><br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Poema
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  2<br><br>En su llama mortal la luz te envuelve.<br>
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Absorta
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , pÃ¡lida doliente, asÃ­ situada<br>contra las viejas hÃ©lices del crepÃºsculo<br>que en torno a ti da vueltas.<br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Muda
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , mi amiga,<br>sola en lo solitario de esta hora de muertes<br>y llena de las vidas del fuego,<br>pura heredera del dÃ­a destruido.<br>Del sol cae un racimo en tu vestido oscuro.<br>De la noche las grandes raÃ­ces<br>crecen de
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sÃºbito
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  desde tu alma,<br>y a lo exterior regresan las cosas en ti ocultas.<br>de modo que un pueblo pÃ¡lido y azul<br>de ti reciÃ©n nacido se alimenta.<br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Oh
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  grandiosa y fecunda y magnÃ©tica esclava<br>cÃ­rculo que en negro y dorado sucede:<br>erguida, trata y logra una creaciÃ³n tan viva<br>que sucumben sus flores, y llena es de tristeza.<br><br><br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Poema
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  3<br><br>Ah vastedad de pinos, rumor de olas quebrÃ¡ndose,<br>lento juego de luces, campana solitaria,<br>crepÃºsculo cayendo en tus ojos, muÃ±eca,<br>caracola terrestre, en ti la tierra canta!<br>En ti los rÃ­os cantan y mi alma en ellos huye<br>como tÃº lo desees y hacia donde tÃº quieras.<br>MÃ¡rcame mi camino en tu arco de esperanza<br>y soltarÃ© en delirio mi bandada de flechas.<br>En torno a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mÃ­
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  estoy viendo tu cintura de niebla<br>y tu silencio acosa mis hor
