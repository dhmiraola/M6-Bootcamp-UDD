# %% [markdown]
# **ANÁLISIS MORFOLÓGICO**
#
#
# Este programa realiza el análisis morfológico del tipo **lematización** de textos de entrada en **Español**. El programa utiliza métodos de la biblioteca **[SPaCY](https://spacy.io/)** para procesamiento de lenguaje natural.

# %% [markdown]
# Primero, debemos instalar la biblioteca SpacY. Luego, debemos cargar un modelo de SpacY pre-entrenado para textos de noticias en Español (*es_core_news_sm*)

# %%
# !pip install spacy
# !python -m spacy download es_core_news_sm

# %% [markdown]
# Una vez instaladas, utilizamos algunas bibliotecas para NLP y otros utitlitarios.

# %%
import es_core_news_sm

# %% [markdown]
# Luego, definimos algunas funciones que nos serán útiles.
#
# La función **LeerTexto(NombreArchivo)** lee un archivo de texto en español, lo separa según puntuaciones simples ("."), y retorna el texto separado en varias oraciones.

# %%
def LeerTexto(NombreArchivo):
    f = open(NombreArchivo, 'r', encoding="latin1")
    texto = f.read().split('.')
    f.close()
    return(texto)

# %% [markdown]
# Luego, definimos la función **Lematizar(oracion)**, que recibe una oración de texto, y genera un string con cada uno de los lemas de cada palabra de la oración. Para esto, se utiliza  el método **nlp(..)** de Spacy. A diferencia de otros frameworks para NLP (i.e., NLTK), SpaCY realiza varios análisis simultáneamente para una misma oración con el mismo método **nlp(..)**: lematización, POS tagging, tokenización, etc. En otras bibliotecas, cada análisis requiere métodos/funciones diferentes.
#
# Luego, generamos una lista con cada uno de los lemas obtenidos por **nlp(..)**, y se retorna un string con los lemas concatenados.

# %%
def Lematizar(oracion):
   doc = nlp(oracion)
   lemas = [token.lemma_ for token in doc]
   return(" ".join(lemas))

# %% [markdown]
# Una vez definidas todas las funciones, ejecutamos nuestro programa principal que inicializa variables y métodos, e invoca a las funciones definidas previamente.
#
# Especificamos el nombre del archivo que deseamos analizar (**NO se le olvide cargarlos en su directorio!!**). Luego, inicializamos nuestro método **nlp(..)** para que cargue el modelo de NLP pre-entrenado en Español:

# %%
NOMBRE_ARCHIVO = r'C:\Users\Usuario\Big Data\Text Mining\1 Nube de palabras/neruda.txt'

# %%
nlp = es_core_news_sm.load()

# %% [markdown]
# Leemos el texto especificado:

# %%
oraciones = LeerTexto(NOMBRE_ARCHIVO)

# %%
print(oraciones)
len(oraciones)
# Out:
# ['Poema 1\n\nCuerpo de mujer, blancas colinas, muslos blancos,\nte pareces al mundo en tu actitud de entrega', '\nMi cuerpo de labriego salvaje te socava\ny hace saltar el hijo del fondo de la tierra', '\nFui solo como un tÃºnel', ' De mÃ\xad huÃ\xadan los pÃ¡jaros\ny en mÃ\xad la noche entraba su invasiÃ³n poderosa', '\nPara sobrevivirme te forjÃ© como un arma,\ncomo una flecha en mi arco, como una piedra en mi honda', '\nPero cae la hora de la venganza, y te amo', '\nCuerpo de piel, de musgo, de leche Ã¡vida y firme', '\nAh los vasos del pecho! Ah los ojos de ausencia!\nAh las rosas del pubis! Ah tu voz lenta y triste!\nCuerpo de mujer mÃ\xada, persistirÃ¡ en tu gracia', '\nMi sed, mi ansia sin limite, mi camino indeciso!\nOscuros cauces donde la sed eterna sigue,\ny la fatiga sigue, y el dolor infinito', '\n\nPoema 2\n\nEn su llama mortal la luz te envuelve', '\nAbsorta, pÃ¡lida doliente, asÃ\xad situada\ncontra las viejas hÃ©lices del crepÃºsculo\nque en torno a ti da vueltas', '\nMuda, mi amiga,\nsola en lo solitario de esta hora de muertes\ny llena de las vidas del fuego,\npura heredera del dÃ\xada destruido', '\nDel sol cae un racimo en tu vestido oscuro', '\nDe la noche las grandes raÃ\xadces\ncrecen de sÃºbito desde tu alma,\ny a lo exterior regresan las cosas en ti ocultas', '\nde modo que un pueblo pÃ¡lido y azul\nde ti reciÃ©n nacido se alimenta', '\nOh grandiosa y fecunda y magnÃ©tica esclava\ncÃ\xadrculo que en negro y dorado sucede:\nerguida, trata y logra una creaciÃ³n tan viva\nque sucumben sus flores, y llena es de tristeza', '\n\n\nPoema 3\n\nAh vastedad de pinos, rumor de olas quebrÃ¡ndose,\nlento juego de luces, campana solitaria,\ncrepÃºsculo cayendo en tus ojos, muÃ±eca,\ncaracola terrestre, en ti la tierra canta!\nEn ti los rÃ\xados cantan y mi alma en ellos huye\ncomo tÃº lo desees y hacia donde tÃº quieras', '\nMÃ¡rcame mi camino en tu arco de esperanza\ny soltarÃ© en delirio mi bandada de flechas', '\nEn torno a mÃ\xad estoy viendo tu cintura de niebla\ny tu silencio acosa mis horas perseguidas,\ny eres tÃº con tus brazos de piedra transparente\ndonde mis besos anclan y mi hÃºmeda ansia anida', '\nAh tu voz misteriosa que el amor tiÃ±e y dobla\nen el atardecer resonante y muriendo!\nAsÃ\xad en horas profundas sobre los campos he visto\ndoblarse las espigas en la boca del viento', '\n\n\nPoema 4\n\nEs la maÃ±ana llena de tempestad\nen el corazÃ³n del verano', '\nComo paÃ±uelos blancos de adiÃ³s viajan las nubes,\nel viento las sacude con sus viajeras manos', '\nInnumerable corazÃ³n del viento\nlatiendo sobre nuestro silencio enamorado', '\nZumbando entre los Ã¡rboles, orquestal y divino,\ncomo una lengua llena de guerras y de cantos', '\nViento que lleva en rÃ¡pido robo la hojarasca\ny desvÃ\xada las flechas latientes de los pÃ¡jaros', '\nViento que la derriba en ola sin espuma\ny sustancia sin peso, y fuegos inclinado', '\nSe rompe y se sumerge su volumen de besos\ncombatido en la puerta del viento del verano', '\n\n\nPoema 5\n\nPara que tÃº me oigas\nmis palabras\nse adelgazan a veces\ncomo las huellas de las gaviotas en las playas', '\nCollar, cascabel ebrio\npara tus manos suaves como las uvas', '\nY las miro lejanas mis palabras', '\nMÃ¡s que mÃ\xadas son tuyas', '\nVan trepando en mi viejo dolor como las yedras', '\nEllas trepan asÃ\xad por las paredes hÃºmedas', '\nEres tÃº la culpable de este juego sangriento', '\nEllas estÃ¡n huyendo de mi guarida oscura', '\nTodo lo llenas tÃº, todo lo llenas', '\nAntes que tÃº poblaron la soledad que ocupas,\ny estÃ¡n acostumbradas mÃ¡s que tÃº a mi tristeza', '\nAhora quiero que digan lo que quiero decirte\npara que tÃº las oigas como quiero que me oigas', '\nEl viento de la angustia aÃºn las suele arrastrar', '\nHuracanes de sueÃ±os aÃºn a veces las tumban\nEscuchas otras voces en mi voz dolorida', '\nLlanto de viejas bocas, sangre de viejas sÃºplicas', '\nÃ\x81mame, compaÃ±era', ' No me abandones', ' SÃ\xadgueme', '\nSÃ\xadgueme, compaÃ±era, en esa ola d ...
# 323

# %% [markdown]
# Creamos una lista con cada una de las oraciones del texto *lematizadas*, y luego las mostramos.

# %%
texto_lematizado  = [Lematizar(oracion) for oracion in oraciones]
print(texto_lematizado)
# Out:
# ['Poema 1 \n\n Cuerpo de mujer , blanca colina , muslo blanco , \n tú parecer al mundo en tu actitud de entrega', '\n mi cuerpo de labriego salvaje tú socavar \n y hacer saltar el hijo del fondo de el tierra', '\n fui solo como uno tãºnel', '  de mÃ\xad huã\xadan el pã¡jaro \n y en mÃ\xad el noche entrar su invasiã³n poderoso', '\n para sobrevivir yo tú forjÃ © como uno arma , \n como uno flecha en mi arco , como uno piedra en mi honda', '\n pero caer el hora de el venganza , y tú amar', '\n cuerpo de piel , de musgo , de leche ã¡vido y firme', '\n ah el vaso del pecho ! ah el ojo de ausencia ! \n ah el rosa del pubis ! Ah tu voz lento y triste ! \n cuerpo de mujer mÃ\xada , persistirã ¡ en tu gracia', '\n mi sed , mi ansia sin limite , mi camino indeciso ! \n Oscuros cauce donde el sed eterno seguir , \n y el fatiga seguir , y el dolor infinito', '\n\n Poema 2 \n\n En su llama mortal el luz tú envolver', '\n Absorta , pã¡lido doliente , asã\xad situado \n contra el viejo hÃ © liz del crepãºsculo \n que en torno a tú dar vuelta', '\n Muda , mi amiga , \n solo en él solitario de este hora de muerte \n y lleno de el vida del fuego , \n puro heredera del dÃ\xada destruido', '\n del sol caer uno racimo en tu vestido oscuro', '\n de el noche el grande raã\xadz \n crecer de sãºbito desde tu alma , \n y a él exterior regresar el cosa en tú oculto', '\n de modo que uno pueblo pã¡lido y azul \n de tú reciÃ © n nacido él alimentar', '\n Oh grandioso y fecundo y magnÃ © tico esclava \n cã\xadrculo que en negro y dorado suceder : \n erguido , tratar y lograr uno creaciã³n tanto vivo \n que sucumbir su flor , y lleno ser de tristeza', '\n\n\n Poema 3 \n\n Ah vastedad de pino , rumor de ola quebrã¡ndo él , \n lento juego de luz , campana solitario , \n crepãºsculo caer en tu ojo , muÃ±eca , \n caracola terrestre , en tú el tierra canta ! \n En tú el rã\xado cantar y mi alma en él huir \n como tÃº él desees y hacia donde tÃº querer', '\n MÃ¡rcame mi camino en tu arco de esperanza \n y soltarÃ © en delirio mi bandada de flecha', '\n en torno a mÃ\xad estar ver tu cintura de niebla \n y tu silencio acós mi hora perseguido , \n y ser tÃº con tu brazo de piedra transparente \n donde mi beso anclar y mi hãºmeda ansia anido', '\n Ah tu voz misterioso que el amor tiÃ±e y doblar \n en el atardecer resonante y morir ! \n asã\xad en hora profundo sobre el campo haber ver \n doblar él el espiga en el boca del viento', '\n\n\n Poema 4 \n\n ser el maã±ana lleno de tempestad \n en el corazã³n del verano', '\n como paã±uelo blanco de adiã³s viajar el nube , \n el viento el sacude con su viajera mano', '\n Innumerable corazã³n del viento \n lateir sobre nuestro silencio enamorado', '\n Zumbando entre el ã¡rbol , orquestal y divino , \n como uno lengua lleno de guerra y de canto', '\n Viento que llevar en rã¡pido robo el hojarasca \n y desvã\xadar el flecha latient de el pã¡jaro', '\n Viento que él derribar en ola sin espuma \n y sustancia sin peso , y fuego inclinado', '\n él romper y él sumerge su volumen de beso \n combatido en el puerta del viento del verano', '\n\n\n Poema 5 \n\n Para que tÃº yo oigar \n mi palabra \n él adelgazar a veces \n como el huella de el gaviota en el playa', '\n Collar , cascabel ebrio \n para tu mano suave como el uva', '\n y él mirar lejana mi palabra', '\n mã¡s que mÃ\xadas ser tuya', '\n ir trepar en mi viejo dolor como el yedra', '\n Ellas trepar asã\xad por el pared hãºmeda', '\n Eres tÃº el culpable de este juego sangriento', '\n Ellas estã¡n huir de mi guarida oscuro', '\n todo él llena tÃº , todo él llena', '\n antes que tÃº poblar el soledad que ocupas , \n y estã¡n acostumbrado mã¡s que tÃº a mi tristeza', '\n ahora querer que decir él que querer decirte \n para que tÃº el oiga como querer que yo oigar', '\n el viento de el angustia aÃºn él soler arrastrar', '\n huracanser de sueÃ±os aãºn a veces él tumr \n escucha otro voz en mi voz dolorido', '\n llanto de vieja boca , sangre de vieja sãºplica', '\n Ã\x81mame , com ...
